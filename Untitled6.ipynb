# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(0,20,0.01)
y=np.cos(x)**2
plt.plot(x,y)

# %%
print("Average of cycle:"+str(np.average(y)))
# Out:
# Average of cycle:0.5095219712978117
